# %%
! pip install openpyxl
! pip install --upgrade xlrd
! pip install msoffcrypto-tool

# %%
# Out:
# Saved file: 2024-Data-Cleaned/Patients/SB-001 1336.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-002 572.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-003 1064.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-004 1823.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-005 281.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-006 1327.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-007 309.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-008 2100.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-009 975.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-010 266.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-011 2093.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-012 594.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-013 773.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-014 1793.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-015 640.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-016 667.csv
# Saved file: 2024-Data-Cleaned/Patients/SB-017 1990.csv
# ...
